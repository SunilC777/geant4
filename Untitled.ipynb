// %%
TChain t("t")
// Out:
// (TChain &) Name: t Title:

// %%
t.Add("gears.root")
// Out:
// (int) 1

// %%
TCanvas c
// Out:
// (TCanvas &) Name: c1 Title: c1

// %%
t.Draw("et")
// Out:
// Error in <TFile::TFile>: file /root/geant4/gears.root does not exist
